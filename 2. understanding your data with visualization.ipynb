# %%
from pandas import read_csv
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import Line2D

# %%
filename ="C:\\Users\\HP\\pythonProjects\\1. Datasets\\pima-indians-diabetes.csv"
data = read_csv(filename)
peek = data.head(10)
print(peek)
# Out:
#    pregnancy  plasma  pressure  skin  insulin  mass  pedigree  age  diagnosis
# 0          6     148        72    35        0  33.6     0.627   50          1
# 1          1      85        66    29        0  26.6     0.351   31          0
# 2          8     183        64     0        0  23.3     0.672   32          1
# 3          1      89        66    23       94  28.1     0.167   21          0
# 4          0     137        40    35      168  43.1     2.288   33          1
# 5          5     116        74     0        0  25.6     0.201   30          0
# 6          3      78        50    32       88  31.0     0.248   26          1
# 7         10     115         0     0        0  35.3     0.134   29          0
# 8          2     197        70    45      543  30.5     0.158   53          1
# 9          8     125        96     0        0   0.0     0.232   54          1

# %%
data.hist()
plt.show()

# %%
#univariate density plot
data.plot(layout=(3,3), kind='density', grid='on', sharex=False)
plt.show()

# %%
#box and whisker plot
data.plot(kind='bar', layout=(3,3), sharex=False, sharey=False)
plt.show()

# %%
#Multivariate plot
correlations = data.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,5,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels('names')
ax.set_yticklabels('names')
plt.show()
